# %%
import cv2
import pickle
import os
import numpy as np
import datetime
import matplotlib.pyplot as plt
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, load_model
from tensorflow.python import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, TensorBoard
from helpers import resize_to_fit  

# # 不区分大小写的字母文件夹
LETTER_IMAGES_FOLDER = "extracted_letter_images"
# # 不区分大小写的模型保存位置
MODEL_FILENAME = "captcha_model.hdf5"
# # 不区分大小写的转换对象保存位置
MODEL_LABELS_FILENAME = "model_labels.dat"

# # 区分大小写的文件夹
# LETTER_IMAGES_FOLDER = "extracted_letter_images_"
# # 区分大小写的模型保存位置
# MODEL_FILENAME = "captcha_model_.hdf5"
# # 区分大小写的转换对象保存位置
# MODEL_LABELS_FILENAME = "model_labels_.dat"

# initialize the data and labels
data = []
labels = []

# 循环输入图像
for image_file in paths.list_images(LETTER_IMAGES_FOLDER):   # 1
    # 加载图像并将其转换为灰度图像
    image = cv2.imread(image_file)                           # 2   
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)          # 3 

    # 改变图像大小
    image = resize_to_fit(image, 30, 30) # 引入的函数

    # A增加一个维度
    image = np.expand_dims(image, axis=2)

    # 根据字母所在的文件夹来获取字母的名称
    label = image_file.split(os.path.sep)[-2]                # 4
    if len(label)==2: 
        label = label[0]
   
    # 将字母图像及其标签添加到训练数据中
    data.append(image)
    #print(data)
    labels.append(label)

# 将原始像素调整为[0，1]范围（这可以改善训练）
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)    
    
# 分为训练集和测试集
(X_train, X_test, Y_train, Y_test) = train_test_split(data, labels, test_size=0.2, random_state=0)
'''
image_gen_train = ImageDataGenerator(
    rotation_range=45, # 随机45度度旋转
    width_shift_range=.15, #随机宽度偏移 [-0.15,0.15)
    height_shift_range=.15, #随机高度偏移 [-0.15,0.15)
)
'''

# 将标签转换为独热码
lb = LabelBinarizer().fit(Y_train) # 构建一个转换对象
Y_train = lb.transform(Y_train)
Y_test = lb.transform(Y_test)

# 保存对象，供以后使用模型解码其预测的含义时使用
with open(MODEL_LABELS_FILENAME, "wb") as f:
    pickle.dump(lb, f)                                      # 5


# 搭建神经网络
model = Sequential()

# 第一个带有最大池化层的卷积层
model.add(Conv2D(32, (3, 3), 
                 padding="same", 
                 input_shape=(30, 30, 1), 
                 activation="relu",
                 kernel_regularizer = keras.regularizers.l2(0.01),
                 bias_regularizer = keras.regularizers.l2(0.01))) # 6
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))


# 第二个带有最大池化层的卷积层
model.add(Conv2D(64, (3, 3), 
                 padding="same", 
                 activation="relu" ,
                 kernel_regularizer = keras.regularizers.l2(0.01)))                 
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# 第三个卷积层
model.add(Conv2D(64, (3, 3), 
                 padding="same", 
                 activation="relu",
                 kernel_regularizer = keras.regularizers.l2(0.01)))

# 增加Dropout层来避免过拟合
model.add(Dropout(0.4))

# 500个神经元的隐藏层
model.add(Flatten())
model.add(Dense(500, activation="relu"))#  kernel_regularizer=keras.regularizers.l2(0.01)

# 增加Dropout层来避免过拟合
model.add(Dropout(0.3))

# 输出层
# model.add(Dense(36, activation="softmax"))
model.add(Dense(36, activation="softmax"))


model.build()
model.summary()

# 构建模型
model.compile(loss="categorical_crossentropy", optimizer="Adam", metrics=["accuracy"]) # 7

current_time = datetime.datetime.now().strftime("%Y.%m.%d_%H-%M-%S")
logdir = os.path.join('cnn_callbacks', current_time)
if not os.path.exists(logdir):
    os.mkdir(logdir)
    
callbacks = [ModelCheckpoint(MODEL_FILENAME,monitor='val_loss',
                             save_weights_only=False, verbose=1, save_best_only=True, period=1),           
            TensorBoard(log_dir= logdir,histogram_freq=1,
                        write_graph=True, write_grads=False, write_images=True,
                        embeddings_freq=0, embeddings_layer_names=None,
                        embeddings_metadata=None, embeddings_data=None, update_freq=500
                        )# tensorboard --logdir=train
            ]

# 加载断点，训练神经网络

if os.path.exists(MODEL_FILENAME):
    model = load_model(MODEL_FILENAME)
    # 若成功加载前面保存的参数，输出下面的信息
    print("checkpoint_loaded")

history = model.fit(X_train, Y_train, batch_size=32, epochs=20, 
                    validation_data=(X_test, Y_test), verbose=1, callbacks = callbacks)
 
# 绘制训练 & 验证的准确率值
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# 绘制训练 & 验证的损失值
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()


model.evaluate(X_test, Y_test)

# model.save_weights('model_weights.h5')

# Save the trained model to disk
# model.save(MODEL_FILENAME)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 30, 30, 32)        320
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 3136)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 500)               1568500
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 36)                18036
# =================================================================
# Total params: 1,642,280
# Trainable params: 1,642,280
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2980 samples, validate on 746 samples
# Epoch 1/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 3.5160 - accuracy: 0.1694
# Epoch 00001: val_loss improved from inf to 2.24700, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 3.5139 - accuracy: 0.1698 - val_loss: 2.2470 - val_accuracy: 0.4263
# Epoch 2/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 1.5955 - accuracy: 0.5786
# Epoch 00002: val_loss improved from 2.24700 to 1.03211, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 3s 1ms/sample - loss: 1.5954 - accuracy: 0.5789 - val_loss: 1.0321 - val_accuracy: 0.7909
# Epoch 3/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.9756 - accuracy: 0.7728
# Epoch 00003: val_loss improved from 1.03211 to 0.77611, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.9759 - accuracy: 0.7728 - val_loss: 0.7761 - val_accuracy: 0.8458
# Epoch 4/20
# 2944/2980 [============================>.] - ETA: 0s - loss: 0.7236 - accuracy: 0.8516
# Epoch 00004: val_loss improved from 0.77611 to 0.57349, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.7233 - accuracy: 0.8513 - val_loss: 0.5735 - val_accuracy: 0.8995
# Epoch 5/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.6069 - accuracy: 0.8821
# Epoch 00005: val_loss improved from 0.57349 to 0.55964, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 3s 1ms/sample - loss: 0.6068 - accuracy: 0.8822 - val_loss: 0.5596 - val_accuracy: 0.9021
# Epoch 6/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.5663 - accuracy: 0.8894
# Epoch 00006: val_loss did not improve from 0.55964
# 2980/2980 [==============================] - 3s 1ms/sample - loss: 0.5661 - accuracy: 0.8896 - val_loss: 0.5684 - val_accuracy: 0.8914
# Epoch 7/20
# 2944/2980 [============================>.] - ETA: 0s - loss: 0.4579 - accuracy: 0.9239
# Epoch 00007: val_loss improved from 0.55964 to 0.43161, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.4567 - accuracy: 0.9245 - val_loss: 0.4316 - val_accuracy: 0.9330
# Epoch 8/20
# 2944/2980 [============================>.] - ETA: 0s - loss: 0.4319 - accuracy: 0.9243
# Epoch 00008: val_loss improved from 0.43161 to 0.42626, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.4314 - accuracy: 0.9242 - val_loss: 0.4263 - val_accuracy: 0.9370
# Epoch 9/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.3933 - accuracy: 0.9368
# Epoch 00009: val_loss improved from 0.42626 to 0.39847, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.3940 - accuracy: 0.9362 - val_loss: 0.3985 - val_accuracy: 0.9410
# Epoch 10/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.3934 - accuracy: 0.9382
# Epoch 00010: val_loss did not improve from 0.39847
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.3931 - accuracy: 0.9383 - val_loss: 0.4120 - val_accuracy: 0.9236
# Epoch 11/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.3352 - accuracy: 0.9513
# Epoch 00011: val_loss improved from 0.39847 to 0.38224, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.3352 - accuracy: 0.9513 - val_loss: 0.3822 - val_accuracy: 0.9397
# Epoch 12/20
# 2944/2980 [============================>.] - ETA: 0s - loss: 0.3251 - accuracy: 0.9494 ETA: 1s
# Epoch 00012: val_loss improved from 0.38224 to 0.35335, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 5s 2ms/sample - loss: 0.3252 - accuracy: 0.9493 - val_loss: 0.3533 - val_accuracy: 0.9504
# Epoch 13/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.3134 - accuracy: 0.9519
# Epoch 00013: val_loss did not improve from 0.35335
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.3132 - accuracy: 0.9520 - val_loss: 0.3599 - val_accuracy: 0.9410
# Epoch 14/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.3149 - accuracy: 0.9526
# Epoch 00014: val_loss did not improve from 0.35335
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.3151 - accuracy: 0.9523 - val_loss: 0.3700 - val_accuracy: 0.9437
# Epoch 15/20
# 2944/2980 [============================>.] - ETA: 0s - loss: 0.2925 - accuracy: 0.9555 ETA: 0s - loss: 0
# Epoch 00015: val_loss improved from 0.35335 to 0.33904, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.2938 - accuracy: 0.9554 - val_loss: 0.3390 - val_accuracy: 0.9504
# Epoch 16/20
# 2944/2980 [============================>.] - ETA: 0s - loss: 0.2976 - accuracy: 0.9565
# Epoch 00016: val_loss did not improve from 0.33904
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.2983 - accuracy: 0.9564 - val_loss: 0.3491 - val_accuracy: 0.9450
# Epoch 17/20
# 2944/2980 [============================>.] - ETA: 0s - loss: 0.2722 - accuracy: 0.9633
# Epoch 00017: val_loss did not improve from 0.33904
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.2725 - accuracy: 0.9631 - val_loss: 0.3661 - val_accuracy: 0.9357
# Epoch 18/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.2803 - accuracy: 0.9617
# Epoch 00018: val_loss improved from 0.33904 to 0.33705, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.2801 - accuracy: 0.9617 - val_loss: 0.3370 - val_accuracy: 0.9491
# Epoch 19/20
# 2944/2980 [============================>.] - ETA: 0s - loss: 0.2530 - accuracy: 0.9674
# Epoch 00019: val_loss improved from 0.33705 to 0.33077, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.2526 - accuracy: 0.9678 - val_loss: 0.3308 - val_accuracy: 0.9491
# Epoch 20/20
# 2976/2980 [============================>.] - ETA: 0s - loss: 0.2394 - accuracy: 0.9667
# Epoch 00020: val_loss improved from 0.33077 to 0.31058, saving model to captcha_model.hdf5
# 2980/2980 [==============================] - 4s 1ms/sample - loss: 0.2394 - accuracy: 0.9668 - val_loss: 0.3106 - val_accuracy: 0.9450
# 746/746 [==============================] - 0s 250us/sample - loss: 0.3106 - accuracy: 0.9450
# [0.3105770606777304, 0.9450402]

# %% [markdown]
# 1. 列出路径下的文件名或图片名并且存入list列表，进行for循环取出，构建绝对路径即可对该文件进行遍历操作。
#
# 2. imread函数有两个参数，第一个参数是图片路径，第二个参数表示读取图片的形式，有三种：
#    cv2.IMREAD_COLOR：加载彩色图片，这个是默认参数，可以直接写1。
#    cv2.IMREAD_GRAYSCALE：以灰度模式加载图片，可以直接写0。
#    cv2.IMREAD_UNCHANGED：包括alpha，可以直接写-1
#
# 3. p1是需要转换的图片，p2是转换成何种格式。
#    cv2.COLOR_BGR2RGB 将BGR格式转换成RGB格式
#    cv2.COLOR_BGR2GRAY 将BGR格式转换成灰度图片
#
# 4. os.path.sep:路径分隔符  linux下是’/’
#
# 5. 一、dump()方法
#     pickle.dump(obj, file, [,protocol])
#     注释：序列化对象，将对象obj保存到文件file中去。参数protocol是序列化模式，默认是0（ASCII协议，表示以文本的形式进行序列化），protocol的值   还可以是1和2（1和2表示以二进制的形式进行序列化。其中，1是老式的二进制协议；2是新二进制协议）。file表示保存到的类文件对象，file必须有       write()接口，file可以是一个以'w'打开的文件或者是一个StringIO对象，也可以是任何可以实现write()接口的对象。
#    二、load()方法
#     pickle.load(file)
#    注释：反序列化对象，将文件中的数据解析为一个python对象。file中有read()接口和readline()接口
#
# 6. conv2d主要实现了输入张量与设定卷积核的卷积操作
#     tf.nn.conv2d(
#     input,  输入
#     filter,  卷积核
#     strides,  滑动步长
#     padding,   图像边沿填充的方式
#     use_cudnn_on_gpu=True,
#     data_format='NHWC',
#     dilations=[1, 1, 1, 1],
#     name=None
# )
# 7. - categorical_crossentropy要求target为onehot编码。
#    - sparse_categorical_crossentropy要求target为非onehot编码，函数内部进行onehot编码实现。
