# %%
import cv2
import pickle
import os
import numpy as np
import datetime
import matplotlib.pyplot as plt
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras import Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, TensorBoard
from helpers import resize_to_fit  

# 不区分大小写的字母文件夹
LETTER_IMAGES_FOLDER = "extracted_letter_images"
# 不区分大小写的模型保存位置
MODEL_FILENAME = "captcha_model.hdf5"
# 不区分大小写的转换对象保存位置
MODEL_LABELS_FILENAME = "model_labels.dat"

# # 区分大小写的文件夹
# LETTER_IMAGES_FOLDER = "extracted_letter_images_"
# # 区分大小写的模型保存位置
# MODEL_FILENAME = "captcha_model_.hdf5"
# # 区分大小写的转换对象保存位置
# MODEL_LABELS_FILENAME = "model_labels_.dat"

# initialize the data and labels
data = []
labels = []

# 循环输入图像
for image_file in paths.list_images(LETTER_IMAGES_FOLDER):   # 1
    # 加载图像并将其转换为灰度图像
    image = cv2.imread(image_file)                           # 2   
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)          # 3 

    # 改变图像大小
    image = resize_to_fit(image, 30, 30) # 引入的函数

    # A增加一个维度
    image = np.expand_dims(image, axis=2)

    # 根据字母所在的文件夹来获取字母的名称
    label = image_file.split(os.path.sep)[-2]                # 4
    if len(label)==2: 
        label = label[0]
   
    # 将字母图像及其标签添加到训练数据中
    data.append(image)
    #print(data)
    labels.append(label)

# 将原始像素调整为[0，1]范围（这可以改善训练）
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)    
    
# 分为训练集和测试集
(X_train, X_test, Y_train, Y_test) = train_test_split(data, labels, test_size=0.2, random_state=0)

# 图像增强
image_gen_train = ImageDataGenerator(
    rotation_range=45, # 随机45度旋转
    height_shift_range=.15, #随机高度偏移 [-0.15,0.15)
)


# 将标签转换为独热码
lb = LabelBinarizer().fit(Y_train) # 构建一个转换对象
Y_train = lb.transform(Y_train)
Y_test = lb.transform(Y_test)

# 保存对象，供以后使用模型解码其预测的含义时使用
with open(MODEL_LABELS_FILENAME, "wb") as f:
    pickle.dump(lb, f)                                      # 5

class CNNWhu(Model):
    # 搭建神经网络
    def __init__(self):
        super(CNNWhu, self).__init__()

        # 第一个带有最大池化层的卷积层
        self.c1 = Conv2D(32, (3, 3), 
                         padding="same", 
                         input_shape=(30, 30, 1), 
                         kernel_regularizer = keras.regularizers.l2(0.01)
                         ) # 6 bias_regularizer = keras.regularizers.l2(0.01)
        self.b1 = BatchNormalization() # BN层
        self.a1 = Activation('relu')
        self.p1 = AveragePooling2D(pool_size=(2, 2), strides=(2, 2))
        self.d1 = Dropout(0.2)

        # 第二个带有最大池化层的卷积层
        self.c2 = Conv2D(64, (3, 3), 
                         padding="same", 
                         activation="relu" ,
                         kernel_regularizer = keras.regularizers.l2(0.01)
                         )                 
        self.p2 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))

        # 第三个卷积层
        self.c3 = Conv2D(64, (3, 3), 
                         padding="same", 
                         activation="relu",
                         kernel_regularizer = keras.regularizers.l2(0.01))

        # 压缩层
        self.flatten = Flatten()
        
        # 500个神经元的隐藏层
        self.f1 = Dense(500, activation="relu")#  kernel_regularizer=keras.regularizers.l2(0.01)

        # 增加Dropout层来避免过拟合
        self.d2 = Dropout(0.3)

        # 输出层
        # self.f2 = Dense(62, activation="softmax")
        self.f2 = Dense(36, activation="softmax")

        
    def call(self, x):
        x1 = self.c1(x)
        x1 = self.b1(x)
        x1 = self.a1(x)
        x1 = self.p1(x)
        x1 = self.d1(x)

        x2 = self.c2(x1)
        x2 = self.p2(x2)

        x3 = self.c3(x2)

        y = self.flatten(x3)
        y = self.f1(y)
        y = self.d2(y)
        y = self.f2(y)

        return y
        
model = CNNWhu()

# 构建模型
model.compile(loss="categorical_crossentropy", optimizer="Adam", metrics=["accuracy"]) # 7

"""
current_time = datetime.datetime.now().strftime("%Y.%m.%d_%H-%M-%S")
logdir = os.path.join('cnn_callbacks_', current_time)
if not os.path.exists(logdir):
    os.mkdir(logdir)
"""
# 设置断点
callbacks = [ModelCheckpoint(MODEL_FILENAME,monitor='val_loss',
                             save_weights_only=False, verbose=1, save_best_only=True, period=1)]         
""" # 网络可视化
            TensorBoard(log_dir= logdir,histogram_freq=1,
                        write_graph=True, write_grads=False, write_images=True,
                        embeddings_freq=0, embeddings_layer_names=None,
                        embeddings_metadata=None, embeddings_data=None, update_freq=500
                        )# tensorboard --logdir=train
"""

# 加载断点，训练神经网络

if os.path.exists(MODEL_FILENAME):
    model = load_model(MODEL_FILENAME)
    # 若成功加载前面保存的参数，输出下面的信息
    print("checkpoint_loaded")

history = model.fit_generator(image_gen_train.flow(X_train, Y_train, batch_size=32),
                              validation_data=(X_test, Y_test),
                              steps_per_epoch=len(X_train) / 32, epochs=40, 
                              callbacks = callbacks)# 

model.summary()

# 绘制训练 & 验证的准确率值
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# 绘制训练 & 验证的损失值
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()


model.evaluate(X_test, Y_test)

# model.save_weights('model_weights.h5')

# Save the trained model to disk
# model.save(MODEL_FILENAME)
# Out:
# checkpoint_loaded
# WARNING:tensorflow:From <ipython-input-2-8a666fb24116>:176: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 93.125 steps, validate on 746 samples
# Epoch 1/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.5132 - accuracy: 0.8575
# Epoch 00001: val_loss improved from inf to 0.29025, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 44ms/step - loss: 0.5123 - accuracy: 0.8587 - val_loss: 0.2903 - val_accuracy: 0.9343
# Epoch 2/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.4520 - accuracy: 0.8891
# Epoch 00002: val_loss did not improve from 0.29025
# 94/93 [==============================] - 4s 39ms/step - loss: 0.4511 - accuracy: 0.8893 - val_loss: 0.3417 - val_accuracy: 0.9357
# Epoch 3/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.3950 - accuracy: 0.9121
# Epoch 00003: val_loss improved from 0.29025 to 0.28923, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 42ms/step - loss: 0.3950 - accuracy: 0.9124 - val_loss: 0.2892 - val_accuracy: 0.9303
# Epoch 4/40
# 92/93 [============================>.] - ETA: 0s - loss: 0.3666 - accuracy: 0.9088
# Epoch 00004: val_loss improved from 0.28923 to 0.22848, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 45ms/step - loss: 0.3669 - accuracy: 0.9094 - val_loss: 0.2285 - val_accuracy: 0.9665
# Epoch 5/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.3468 - accuracy: 0.9152
# Epoch 00005: val_loss improved from 0.22848 to 0.21943, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 45ms/step - loss: 0.3482 - accuracy: 0.9151 - val_loss: 0.2194 - val_accuracy: 0.9638
# Epoch 6/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.3035 - accuracy: 0.9362
# Epoch 00006: val_loss did not improve from 0.21943
# 94/93 [==============================] - 4s 42ms/step - loss: 0.3055 - accuracy: 0.9356 - val_loss: 0.2261 - val_accuracy: 0.9678
# Epoch 7/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.3054 - accuracy: 0.9322
# Epoch 00007: val_loss improved from 0.21943 to 0.21287, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 43ms/step - loss: 0.3105 - accuracy: 0.9309 - val_loss: 0.2129 - val_accuracy: 0.9692
# Epoch 8/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.3044 - accuracy: 0.9305
# Epoch 00008: val_loss improved from 0.21287 to 0.20902, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 47ms/step - loss: 0.3050 - accuracy: 0.9299 - val_loss: 0.2090 - val_accuracy: 0.9718
# Epoch 9/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.3123 - accuracy: 0.9264
# Epoch 00009: val_loss improved from 0.20902 to 0.20346, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 43ms/step - loss: 0.3114 - accuracy: 0.9268 - val_loss: 0.2035 - val_accuracy: 0.9705
# Epoch 10/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2875 - accuracy: 0.9352
# Epoch 00010: val_loss did not improve from 0.20346
# 94/93 [==============================] - 4s 42ms/step - loss: 0.2863 - accuracy: 0.9359 - val_loss: 0.2113 - val_accuracy: 0.9611
# Epoch 11/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2869 - accuracy: 0.9342
# Epoch 00011: val_loss improved from 0.20346 to 0.19673, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2863 - accuracy: 0.9342 - val_loss: 0.1967 - val_accuracy: 0.9732
# Epoch 12/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2830 - accuracy: 0.9339
# Epoch 00012: val_loss did not improve from 0.19673
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2850 - accuracy: 0.9329 - val_loss: 0.2115 - val_accuracy: 0.9598
# Epoch 13/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.3143 - accuracy: 0.9335
# Epoch 00013: val_loss did not improve from 0.19673
# 94/93 [==============================] - 4s 43ms/step - loss: 0.3137 - accuracy: 0.9336 - val_loss: 0.2219 - val_accuracy: 0.9558
# Epoch 14/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2808 - accuracy: 0.9359
# Epoch 00014: val_loss did not improve from 0.19673
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2843 - accuracy: 0.9349 - val_loss: 0.2161 - val_accuracy: 0.9611
# Epoch 15/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2835 - accuracy: 0.9335
# Epoch 00015: val_loss did not improve from 0.19673
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2831 - accuracy: 0.9336 - val_loss: 0.2104 - val_accuracy: 0.9678
# Epoch 16/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2732 - accuracy: 0.9406
# Epoch 00016: val_loss improved from 0.19673 to 0.19270, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 44ms/step - loss: 0.2718 - accuracy: 0.9413 - val_loss: 0.1927 - val_accuracy: 0.9678
# Epoch 17/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2766 - accuracy: 0.9352
# Epoch 00017: val_loss improved from 0.19270 to 0.18840, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2765 - accuracy: 0.9342 - val_loss: 0.1884 - val_accuracy: 0.9745
# Epoch 18/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2693 - accuracy: 0.9369
# Epoch 00018: val_loss did not improve from 0.18840
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2679 - accuracy: 0.9376 - val_loss: 0.1927 - val_accuracy: 0.9705
# Epoch 19/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2773 - accuracy: 0.9362
# Epoch 00019: val_loss did not improve from 0.18840
# 94/93 [==============================] - 4s 44ms/step - loss: 0.2760 - accuracy: 0.9369 - val_loss: 0.1995 - val_accuracy: 0.9692
# Epoch 20/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2673 - accuracy: 0.9406
# Epoch 00020: val_loss did not improve from 0.18840
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2672 - accuracy: 0.9406 - val_loss: 0.1970 - val_accuracy: 0.9759
# Epoch 21/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2548 - accuracy: 0.9359
# Epoch 00021: val_loss improved from 0.18840 to 0.17585, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2550 - accuracy: 0.9359 - val_loss: 0.1758 - val_accuracy: 0.9786
# Epoch 22/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2605 - accuracy: 0.9400
# Epoch 00022: val_loss did not improve from 0.17585
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2593 - accuracy: 0.9406 - val_loss: 0.2055 - val_accuracy: 0.9665
# Epoch 23/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2434 - accuracy: 0.9481
# Epoch 00023: val_loss did not improve from 0.17585
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2427 - accuracy: 0.9487 - val_loss: 0.2098 - val_accuracy: 0.9584
# Epoch 24/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2572 - accuracy: 0.9396
# Epoch 00024: val_loss did not improve from 0.17585
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2574 - accuracy: 0.9396 - val_loss: 0.1986 - val_accuracy: 0.9584
# Epoch 25/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2572 - accuracy: 0.9403
# Epoch 00025: val_loss did not improve from 0.17585
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2560 - accuracy: 0.9406 - val_loss: 0.1920 - val_accuracy: 0.9678
# Epoch 26/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2483 - accuracy: 0.9430
# Epoch 00026: val_loss did not improve from 0.17585
# 94/93 [==============================] - 4s 42ms/step - loss: 0.2471 - accuracy: 0.9436 - val_loss: 0.2224 - val_accuracy: 0.9625
# Epoch 27/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2390 - accuracy: 0.9461
# Epoch 00027: val_loss did not improve from 0.17585
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2402 - accuracy: 0.9456 - val_loss: 0.1912 - val_accuracy: 0.9611
# Epoch 28/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2484 - accuracy: 0.9396
# Epoch 00028: val_loss improved from 0.17585 to 0.16911, saving model to captcha_model.hdf5
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2473 - accuracy: 0.9399 - val_loss: 0.1691 - val_accuracy: 0.9772
# Epoch 29/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2227 - accuracy: 0.9549
# Epoch 00029: val_loss did not improve from 0.16911
# 94/93 [==============================] - 4s 42ms/step - loss: 0.2228 - accuracy: 0.9547 - val_loss: 0.2033 - val_accuracy: 0.9625
# Epoch 30/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2532 - accuracy: 0.9359
# Epoch 00030: val_loss did not improve from 0.16911
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2525 - accuracy: 0.9359 - val_loss: 0.1995 - val_accuracy: 0.9678
# Epoch 31/40
# 92/93 [============================>.] - ETA: 0s - loss: 0.2486 - accuracy: 0.9441
# Epoch 00031: val_loss did not improve from 0.16911
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2461 - accuracy: 0.9453 - val_loss: 0.1869 - val_accuracy: 0.9705
# Epoch 32/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2479 - accuracy: 0.9427
# Epoch 00032: val_loss did not improve from 0.16911
# 94/93 [==============================] - 4s 43ms/step - loss: 0.2473 - accuracy: 0.9426 - val_loss: 0.1951 - val_accuracy: 0.9718
# Epoch 33/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2377 - accuracy: 0.9454
# Epoch 00033: val_loss did not improve from 0.16911
# 94/93 [==============================] - 4s 44ms/step - loss: 0.2376 - accuracy: 0.9456 - val_loss: 0.2853 - val_accuracy: 0.9410
# Epoch 34/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2238 - accuracy: 0.9542
# Epoch 00034: val_loss did not improve from 0.16911
# 94/93 [==============================] - 4s 44ms/step - loss: 0.2242 - accuracy: 0.9537 - val_loss: 0.1847 - val_accuracy: 0.9718
# Epoch 35/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2396 - accuracy: 0.9430
# Epoch 00035: val_loss did not improve from 0.16911
# 94/93 [==============================] - 4s 45ms/step - loss: 0.2393 - accuracy: 0.9433 - val_loss: 0.2010 - val_accuracy: 0.9678
# Epoch 36/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2197 - accuracy: 0.9535
# Epoch 00036: val_loss did not improve from 0.16911
# 94/93 [==============================] - 4s 44ms/step - loss: 0.2225 - accuracy: 0.9523 - val_loss: 0.1847 - val_accuracy: 0.9665
# Epoch 37/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2206 - accuracy: 0.9488
# Epoch 00037: val_loss did not improve from 0.16911
# 94/93 [==============================] - 5s 49ms/step - loss: 0.2212 - accuracy: 0.9487 - val_loss: 0.1952 - val_accuracy: 0.9611
# Epoch 38/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2336 - accuracy: 0.9474
# Epoch 00038: val_loss did not improve from 0.16911
# 94/93 [==============================] - 5s 51ms/step - loss: 0.2327 - accuracy: 0.9477 - val_loss: 0.1827 - val_accuracy: 0.9651
# Epoch 39/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2335 - accuracy: 0.9423
# Epoch 00039: val_loss did not improve from 0.16911
# 94/93 [==============================] - 4s 47ms/step - loss: 0.2360 - accuracy: 0.9409 - val_loss: 0.1865 - val_accuracy: 0.9651
# Epoch 40/40
# 93/93 [============================>.] - ETA: 0s - loss: 0.2546 - accuracy: 0.9389
# Epoch 00040: val_loss did not improve from 0.16911
# 94/93 [==============================] - 5s 48ms/step - loss: 0.2532 - accuracy: 0.9396 - val_loss: 0.1783 - val_accuracy: 0.9759
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 30, 30, 32)        320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# activation_3 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 500)               1568500
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 36)                18036
# =================================================================
# Total params: 1,642,408
# Trainable params: 1,642,344
# Non-trainable params: 64
# _________________________________________________________________
# 746/746 [==============================] - 0s 253us/sample - loss: 0.1783 - accuracy: 0.9759
# [0.17827836102518896, 0.9758713]

# %% [markdown]
# 1. 列出路径下的文件名或图片名并且存入list列表，进行for循环取出，构建绝对路径即可对该文件进行遍历操作。
#
# 2. imread函数有两个参数，第一个参数是图片路径，第二个参数表示读取图片的形式，有三种：
#    cv2.IMREAD_COLOR：加载彩色图片，这个是默认参数，可以直接写1。
#    cv2.IMREAD_GRAYSCALE：以灰度模式加载图片，可以直接写0。
#    cv2.IMREAD_UNCHANGED：包括alpha，可以直接写-1
#
# 3. p1是需要转换的图片，p2是转换成何种格式。
#    cv2.COLOR_BGR2RGB 将BGR格式转换成RGB格式
#    cv2.COLOR_BGR2GRAY 将BGR格式转换成灰度图片
#
# 4. os.path.sep:路径分隔符  linux下是’/’
#
# 5. 一、dump()方法
#     pickle.dump(obj, file, [,protocol])
#     注释：序列化对象，将对象obj保存到文件file中去。参数protocol是序列化模式，默认是0（ASCII协议，表示以文本的形式进行序列化），protocol的值   还可以是1和2（1和2表示以二进制的形式进行序列化。其中，1是老式的二进制协议；2是新二进制协议）。file表示保存到的类文件对象，file必须有       write()接口，file可以是一个以'w'打开的文件或者是一个StringIO对象，也可以是任何可以实现write()接口的对象。
#    二、load()方法
#     pickle.load(file)
#    注释：反序列化对象，将文件中的数据解析为一个python对象。file中有read()接口和readline()接口
#
# 6. conv2d主要实现了输入张量与设定卷积核的卷积操作
#     tf.nn.conv2d(
#     input,  输入
#     filter,  卷积核
#     strides,  滑动步长
#     padding,   图像边沿填充的方式
#     use_cudnn_on_gpu=True,
#     data_format='NHWC',
#     dilations=[1, 1, 1, 1],
#     name=None
# )
# 7. - categorical_crossentropy要求target为onehot编码。
#    - sparse_categorical_crossentropy要求target为非onehot编码，函数内部进行onehot编码实现。
